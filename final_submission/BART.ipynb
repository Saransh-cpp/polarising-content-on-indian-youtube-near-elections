# %%
# !pip install -qU datasets accelerate
# !pip install -qU transformers[torch]

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd
df = pd.read_csv("./Filtered_labelled_ge_transcripts (1).csv")
encoder = preprocessing.LabelEncoder()
df.rename(columns = {'Label': 'labels'}, inplace=True)
#print(df.head())
encoder.fit(df['labels'])
df['labels']=encoder.transform(df['labels'])
print(df.head())
X_train, X_test, y_train, y_test = train_test_split(df['transcripts'], df['labels'], test_size=0.2, random_state=20)
train = pd.DataFrame([X_train, y_train]).T
train.set_index('transcripts').dropna().to_csv('train.csv')

test = pd.DataFrame([X_test, y_test]).T
test.set_index('transcripts').dropna().to_csv('test.csv')
# Out:
#    Unnamed: 0      videoId                                              title  \
# 0           0  joLk0IPEniA  WILL RAFALE BE A FACTOR THIS ELECTION? | FACEO...
# 1           1  Gc1tf5U7BuU  BJP Manifesto Promises To Secure &amp; Protect...
# 2           2  1BAgeFCwR3o  Reporters Project: Andhra Pradesh’s Politics O...
# 3           3  HKCBxHhnfC4  Reporters Project: Giving Voice To The Real Is...
# 4           4  iLlUz3a4zDg  “I Definitely Don&#39;t Fight A War To Lose” –...
#
#                                          description          published_at  \
# 0  RafaleTwist DAY BEFORE POLLS, RAFALE BLOW TO G...  2019-04-10T16:41:10Z
# 1  BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-08T14:19:22Z
# 2  BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-07T09:22:24Z
# 3  BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-07T09:20:19Z
# 4  On Off Centre Anuradha SenGupta is talking to ...  2019-04-06T10:28:52Z
#
#       channel                                     thumbnail_url  \
# 0  CNN-News18  https://i.ytimg.com/vi/joLk0IPEniA/hqdefault.jpg
# 1  CNN-News18  https://i.ytimg.com/vi/Gc1tf5U7BuU/hqdefault.jpg
# 2  CNN-News18  https://i.ytimg.com/vi/1BAgeFCwR3o/hqdefault.jpg
# 3  CNN-News18  https://i.ytimg.com/vi/HKCBxHhnfC4/hqdefault.jpg
# 4  CNN-News18  https://i.ytimg.com/vi/iLlUz3a4zDg/hqdefault.jpg
#
#                                          transcripts  generated_by_youtube  \
# 0  unanimously rejected government's contention o...                  True
# 1  top story 18 degrees south BJP released manife...                  True
# 2  [Music] reporters project CNN news 18 reporter...                  True
# 3  [Music] reporters project record stories CNN n...                  True
# 4  [Music] film stars stranger electoral politics...                  True
#
#   original_lang  views  comments  likes  \
# 0            en    470         8    5.0
# 1            en    285         2    9.0
# 2            en   1431         3   11.0
# 3            en    146         2    2.0
# 4            en  16396       130  205.0
#
#                                        pre_processed  \
# 0  unanimously reject government \n   contention ...
# 1  story 18 degree south \n   BJP release manifes...
# 2  reporter project CNN news 18 \n   reporter fan...
# 3  reporter project \n   record story CNN news 18...
# 4  film star stranger electoral \n   politic Lok ...
#
#                                             entities  labels
# 0  Hindu -> NORP\ntoday -> DATE\nSupreme Court ->...       2
# 1  18 -> CARDINAL\nBJP -> ORG\ntoday -> DATE\nsha...       2
# 2  CNN -> ORG\n18 -> CARDINAL\nApril 11th -> DATE...       2
# 3  CNN news -> ORG\n18 -> CARDINAL\nPakistan -> G...       0
# 4  Lok Sabha -> ORG\nyear -> DATE\nLok Sabha -> O...       1

# %%
from datasets import load_dataset, load_metric
import numpy as np
model_metric = load_metric('accuracy')
# Out:
# <ipython-input-6-0ac10517b774>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   model_metric = load_metric('accuracy')

# %%
def compute_metric(model_pred):
  print(model_pred)
  preds, labels = model_pred
  # else: preds, labels, acc = model_pred
  preds = np.argmax(preds, -1)
  return model_metric.compute(predictions=preds, references=labels)

# %%
dataset = load_dataset("csv", data_files="train.csv")
test_set = load_dataset("csv", data_files="test.csv")
print(dataset['train']['transcripts'][10])
set(dataset['train']['labels']), dataset
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# registered case 110 tribals attacking police CRPF forest officials Wednesday tribals pelted stones officials amravati injuring around 45 Forest Department officials 20 policemen violence erupted tribals moved fact tribals moved core area reserve [Music] Beshara joining us phone line show case registered 110 tribals attacking government officers share details please that's right incident comes right tribals got agitated goes back 2002 rehabilitation process going many rebels shifted Accola district corporate area since new residence near semi-open town forced change lifestyle look new occupation recently Africa started moving back villages falls tiger suicide danger life living designated reserve also punishable offense Oh Tuesday last see officers concerned reached village force tribal villagers attacked shock weapons access Spears matter entire incident least 15 people injured amravati dozen vehicles destroyed tribals section 144 also enforced area police finally taken action hundred ten tribals understand inquiry also people also involved also underway right obstructing duty government officer assaulting officer duty criminal offense therefore case registered Indian Penal Code thanks much joining us Disha inputs
# ({0, 1, 2},
#  DatasetDict({
#      train: Dataset({
#          features: ['transcripts', 'labels'],
#          num_rows: 1011
#      })
#  }))

# %%
from transformers import TrainingArguments, Trainer
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")
model = AutoModelForSequenceClassification.from_pretrained("facebook/bart-base",num_labels = 3,ignore_mismatched_sizes=True)

def tokenize_fn(samples):
  return tokenizer(samples['transcripts'], max_length=512, truncation=True, padding='max_length')

tokenized_train_set = dataset['train'].map(tokenize_fn, batched=True)
tokenized_test_set = test_set['train'].map(tokenize_fn, batched=True)
# Out:
# Some weights of BartForSequenceClassification were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['classification_head.dense.weight', 'classification_head.dense.bias', 'classification_head.out_proj.weight', 'classification_head.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/1011 [00:00<?, ? examples/s]
# Map:   0%|          | 0/253 [00:00<?, ? examples/s]

# %%
args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    num_train_epochs=20,
    weight_decay=0.01,
    push_to_hub=False,
    label_names=['class'],
    fp16=True,
    save_strategy='no',
    do_eval=True,
    # eval_steps=10,
    logging_strategy="epoch",
    # per_device_train_batch_size=4
)
# fp16 => For using GPU

class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        outputs = model(**inputs)
        loss = outputs.loss
        # print('----------------------------------', model(**inputs), '---------------------------------')
        return (loss, outputs) if return_outputs else loss


trainer = Trainer(model=model,
                  args=args,
                  train_dataset=tokenized_train_set,
                  eval_dataset=tokenized_test_set,
                  compute_metrics=compute_metric
                  )

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2540' max='2540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2540/2540 19:39, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.798700</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.692300</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.586400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.490400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.366600</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.259500</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.178400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.104900</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.068300</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.051400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.028900</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.020300</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.009300</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.013900</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.005300</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.015400</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.012800</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.008700</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.006900</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.002200</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2540, training_loss=0.18603088873343204, metrics={'train_runtime': 1179.9354, 'train_samples_per_second': 17.137, 'train_steps_per_second': 2.153, 'total_flos': 6201264012226560.0, 'train_loss': 0.18603088873343204, 'epoch': 20.0})

# %%
pred = trainer.predict(tokenized_train_set)
from sklearn.metrics import accuracy_score
import torch.nn.functional as F
a = F.softmax(torch.tensor(pred.predictions[1], dtype=torch.float)).argmax(-1)
accuracy_score(a, y_train)
# Out:
# <ipython-input-12-7743a01b91be>:4: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(torch.tensor(pred.predictions[1], dtype=torch.float)).argmax(-1)
# 0.9990108803165183

# %%
pred = trainer.predict(tokenized_test_set)
from sklearn.metrics import accuracy_score
import torch.nn.functional as F
a = F.softmax(torch.tensor(pred.predictions[1], dtype=torch.float)).argmax(-1)
accuracy_score(a, y_test)
# Out:
# <ipython-input-13-28fc1102d561>:4: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(torch.tensor(pred.predictions[1], dtype=torch.float)).argmax(-1)
# 0.7470355731225297

# %%
trainer.save_model('Saved_model_ROBERTA')

# %%
# !zip -r /content/Saved_model_ROBERTA.zip /content/Saved_model_ROBERTA
# Out:
#   adding: content/Saved_model_ROBERTA/ (stored 0%)
#   adding: content/Saved_model_ROBERTA/training_args.bin (deflated 51%)
#   adding: content/Saved_model_ROBERTA/config.json (deflated 51%)
#   adding: content/Saved_model_ROBERTA/model.safetensors (deflated 7%)

# %%
# !mv '/content/Saved_model_ROBERTA.zip' '/content/drive/MyDrive'
