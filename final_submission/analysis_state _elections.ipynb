# %%
# !pip install -qU wordcloud nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import matplotlib.dates as mdates
from collections import OrderedDict

# %%
channels = [
    "CNN-News18",
    "Republic World",
    "India Today",
    "MIRROR NOW",
    "TIMES NOW",
    "DD INDIA",
    "WION",
    "NewsX",
]

# %%
df = pd.read_csv("Filtered_labelled_state_transcripts (1).csv")

# %%
df
# Out:
#       Unnamed: 0      videoId  \
# 0              1  Gc1tf5U7BuU
# 1              2  1BAgeFCwR3o
# 2              3  HKCBxHhnfC4
# 3              4  iLlUz3a4zDg
# 4              5  sLdneSyrx7c
# ...          ...          ...
# 1167        1363  V1pyuUKGEvw
# 1168        1364  qx0a2coAYz4
# 1169        1365  OVUMiE3tCc8
# 1170        1366  mF09iL30OCY
# 1171        1367  j7cN6tGUk2s
#
#                                                   title  \
# 0     BJP Manifesto Promises To Secure &amp; Protect...
# 1     Reporters Project: Andhra Pradesh’s Politics O...
# 2     Reporters Project: Giving Voice To The Real Is...
# 3     “I Definitely Don&#39;t Fight A War To Lose” –...
# 4     NaMo TV launched, Rahul Gandhi To Contest From...
# ...                                                 ...
# 1167  CBI Selection Panel To Meet On 24th January, 2019
# 1168  Church Body&#39;s Letter Accessed By Republic ...
# 1169  Four Nuns Who Spoke Against Franco Mulakkal Sh...
# 1170  After Being Dumped By SP-BSP, Rahul Gandhi For...
# 1171  Reinstated Interim CBI Director Nageswara Rao ...
#
#                                             description          published_at  \
# 0     BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-08T14:19:22Z
# 1     BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-07T09:22:24Z
# 2     BattleOf2019 #ElectionsWithNews18 #LokSabhaEle...  2019-04-07T09:20:19Z
# 3     On Off Centre Anuradha SenGupta is talking to ...  2019-04-06T10:28:52Z
# 4     NaMo TV channel launched, Rahul Gandhi to cont...  2019-04-06T05:00:02Z
# ...                                                 ...                   ...
# 1167  Republic TV is India's no.1 English news chann...  2019-01-16T12:14:38Z
# 1168  Republic TV is India's no.1 English news chann...  2019-01-16T11:29:33Z
# 1169  Republic TV is India's no.1 English news chann...  2019-01-16T11:15:26Z
# 1170  Republic TV is India's no.1 English news chann...  2019-01-15T06:14:38Z
# 1171  Republic TV is India's no.1 English news chann...  2019-01-11T10:56:58Z
#
#              channel                                     thumbnail_url  \
# 0         CNN-News18  https://i.ytimg.com/vi/Gc1tf5U7BuU/hqdefault.jpg
# 1         CNN-News18  https://i.ytimg.com/vi/1BAgeFCwR3o/hqdefault.jpg
# 2         CNN-News18  https://i.ytimg.com/vi/HKCBxHhnfC4/hqdefault.jpg
# 3         CNN-News18  https://i.ytimg.com/vi/iLlUz3a4zDg/hqdefault.jpg
# 4         CNN-News18  https://i.ytimg.com/vi/sLdneSyrx7c/hqdefault.jpg
# ...              ...                                               ...
# 1167  Republic World  https://i.ytimg.com/vi/V1pyuUKGEvw/hqdefault.jpg
# 1168  Republic World  https://i.ytimg.com/vi/qx0a2coAYz4/hqdefault.jpg
# 1169  Republic World  https://i.ytimg.com/vi/OVUMiE3tCc8/hqdefault.jpg
# 1170  Republic World  https://i.ytimg.com/vi/mF09iL30OCY/hqdefault.jpg
# 1171  Republic World  https://i.ytimg.com/vi/j7cN6tGUk2s/hqdefault.jpg
#
#                                             transcripts  generated_by_youtube  \
# 0     top story 18 degrees south BJP released manife...                  True
# 1     [Music] reporters project CNN news 18 reporter...                  True
# 2     [Music] reporters project record stories CNN n...                  True
# 3     [Music] film stars stranger electoral politics...                  True
# 4     come come come come come come come come come c...                  True
# ...                                                 ...                   ...
# 1167  breaking news coming far entire internal battl...                  True
# 1168  Oh leave convent editor dungeon fact official ...                  True
# 1169  pull away uh breaking update Santa Fe's gettin...                  True
# 1170  let's quickly turn attention Congress party sn...                  True
# 1171  pulling away National Council meeting begins B...                  True
#
#      original_lang  views  comments  likes  \
# 0               en    285         2    9.0
# 1               en   1431         3   11.0
# 2               en    146         2    2.0
# 3               en  16396       130  205.0
# 4               en  27536        33  387.0
# ...            ...    ...       ...    ...
# 1167            en    361         0    4.0
# 1168            en    705         6   19.0
# 1169            en  16305        47  104.0
# 1170            en    364         3    6.0
# 1171            en   3645        26   85.0
#
#                                           pre_processed  \
# 0     story 18 degree south \n   BJP release manifes...
# 1     reporter project CNN news 18 \n   reporter fan...
# 2     reporter project \n   record story CNN news 18...
# 3     film star stranger electoral \n   politic Lok ...
# 4     come come come come come \n   come come come c...
# ...                                                 ...
# 1167  breaking news come far \n   entire internal ba...
# 1168  oh leave convent editor \n   dungeon fact offi...
# 1169  pull away uh break \n   update Santa Fe gettin...
# 1170  let quickly turn attention \n   Congress party...
# 1171  pull away National \n   Council meeting begin ...
#
#                                                entities    Label
# 0     18 -> CARDINAL\nBJP -> ORG\ntoday -> DATE\nsha...   ProGov
# 1     CNN -> ORG\n18 -> CARDINAL\nApril 11th -> DATE...   ProGov
# 2     CNN news -> ORG\n18 -> CARDINAL\nPakistan -> G...  AntiGov
# 3     Lok Sabha -> ORG\nyear -> DATE\nLok Sabha -> O...  Neutral
# 4     BJP -> ORG\nCongress -> ORG\nseven -> CARDINAL...   ProGov
# ...                                                 ...      ...
# 1167  CBI -> ORG\nCBI -> ORG\nAlok Varma -> PERSON\n...  Neutral
# 1168  Jesus -> PERSON\nAlfea -> PERSON\nJesus -> PER...  Neutral
# 1169  Santa Fe -> ORG\nFranco -> PERSON\nKerala -> G...  AntiGov
# 1170  Congress -> ORG\nAkhilesh Yadav -> PERSON\nnot...  Neutral
# 1171  National \n    -> ORG\nBJP -> ORG\nCBI -> ORG\...  Neutral
#
# [1172 rows x 16 columns]

# %%
df["channel"] = df["channel"].apply(lambda x: "DD INDIA" if x == "S1mple" else x)

# %%
df["Label"].value_counts()
# Out:
# Label
# Neutral    608
# ProGov     484
# AntiGov     80
# Name: count, dtype: int64

# %%
categorical_label = pd.Series(df["Label"], dtype="category")
categorical_channels = [channels.index(a) for a in df["channel"]]

# %%
plt.hist(categorical_label)
# plt.figtext(0.5, -0.08, "Distribution of ProGov, AntiGov, and neutral videos - Karnataka State Elections 2023.", wrap=True, horizontalalignment='center', fontsize=12)
plt.xlabel("Labels")
plt.ylabel("Number of videos")
# Out:
# Text(0, 0.5, 'Number of videos')

# %%
df["channel"].value_counts()
# Out:
# channel
# WION              330
# MIRROR NOW        199
# DD INDIA          126
# India Today       122
# Republic World    105
# TIMES NOW         103
# NewsX             100
# CNN-News18         87
# Name: count, dtype: int64

# %%
new = df.copy()
new["Label"] = pd.factorize(df['Label'])[0] + 1
new["channel"] = pd.factorize(df['channel'])[0] + 1

xnoise, ynoise = np.random.random(len(df))/2, np.random.random(len(df))/2 # The noise is in the range 0 to 0.5

# Plot the scatterplot
plt.scatter(new["channel"].apply(lambda x: float(x))+xnoise, new["Label"].apply(lambda x: float(x))+ynoise, alpha=0.5)
# You can also set xticks and yticks to be your category names:
plt.xticks([1.25, 2.25, 3.25, 4.25, 5.25, 6.25, 7.25, 8.25], ["CNN-News18", "India Today", "Mirror Now", "Times Now", "DD India", "Wion", "News X", "Republic world"], rotation = 90) # The reason the xticks start at 0.25
plt.yticks([1.25, 2.25, 3.25], ["Pro", "Anti", "Neutral"])

plt.grid()
sns.despine(left=True, bottom=True)
# plt.figtext(0.5, -0.08, "Distribution of ProGov, AntiGov, and neutral videos - Karnataka State Elections 2023.", wrap=True, horizontalalignment='center', fontsize=12)
plt.xlabel("News channel")
plt.ylabel("Label generated using mathematical model")
# Out:
# Text(0, 0.5, 'Label generated using mathematical model')

# %%
sns.countplot(x='Label', hue="channel", data=df)
plt.xlabel("Label generated using mathematical model")
plt.ylabel("Number of uploaded videos")
# Out:
# Text(0, 0.5, 'Number of uploaded videos')

# %%
sns.violinplot(x="Label", y="likes", data=df)
plt.xlabel("Label generated using mathematical model")
plt.ylabel("Number of likes")
# Out:
# Text(0, 0.5, 'Number of likes')

# %%
sns.violinplot(x="Label", y="comments", data=df)
plt.xlabel("Label generated using mathematical model")
plt.ylabel("Number of comments")
# Out:
# Text(0, 0.5, 'Number of comments')

# %%
sns.violinplot(x="Label", y="views", data=df)
plt.xlabel("Label generated using mathematical model")
plt.ylabel("Number of views")
# Out:
# Text(0, 0.5, 'Number of views')

# %%
x = [dt.datetime.strptime(d.split("T")[0],'%Y-%m-%d').date() for d in df["published_at"]]
vid_freq = {}
for _, row in df.iterrows():
    if row["published_at"].split("T")[0] in vid_freq:
        vid_freq[row["published_at"].split("T")[0]] += 1
    else:
        vid_freq[row["published_at"].split("T")[0]] = 1

# %%
ordered = OrderedDict(sorted(vid_freq.items(), key=lambda t: t[0]))

# %%
plt.xticks(rotation=90, fontsize=7)
plt.bar(ordered.keys(), ordered.values(), color='g');
plt.xlabel("Publishing date")
plt.ylabel("Number of all videos published")
plt.xticks(list(ordered.keys())[::3]);

# %%
x = [dt.datetime.strptime(d.split("T")[0],'%Y-%m-%d').date() for d in df[df["Label"] == "Neutral"]["published_at"]]
vid_freq_neutral = {}
for _, row in df[df["Label"] == "Neutral"].iterrows():
    if row["published_at"].split("T")[0] in vid_freq_neutral:
        vid_freq_neutral[row["published_at"].split("T")[0]] += 1
    else:
        vid_freq_neutral[row["published_at"].split("T")[0]] = 1

# %%
ordered_neutral = OrderedDict(sorted(vid_freq_neutral.items(), key=lambda t: t[0]))

# %%
plt.xticks(rotation=90, fontsize=7)
plt.bar(ordered_neutral.keys(), ordered_neutral.values(), color='g');
plt.xlabel("Publishing date")
plt.ylabel("Number of 'Neutral' videos published")
plt.xticks(list(ordered_neutral.keys())[::3]);

# %%
x = [dt.datetime.strptime(d.split("T")[0],'%Y-%m-%d').date() for d in df[df["Label"] == "ProGov"]["published_at"]]
vid_freq_pro = {}
for _, row in df[df["Label"] == "ProGov"].iterrows():
    if row["published_at"].split("T")[0] in vid_freq_pro:
        vid_freq_pro[row["published_at"].split("T")[0]] += 1
    else:
        vid_freq_pro[row["published_at"].split("T")[0]] = 1

# %%
ordered_pro = OrderedDict(sorted(vid_freq_pro.items(), key=lambda t: t[0]))

# %%
plt.xticks(rotation=90, fontsize=7)
plt.bar(ordered_pro.keys(), ordered_pro.values(), color='g');
plt.xlabel("Publishing date")
plt.ylabel("Number of 'ProGov' videos published")
plt.xticks(list(ordered_pro.keys())[::3]);

# %%
x = [dt.datetime.strptime(d.split("T")[0],'%Y-%m-%d').date() for d in df[df["Label"] == "AntiGov"]["published_at"]]
vid_freq_anti = {}
for _, row in df[df["Label"] == "AntiGov"].iterrows():
    if row["published_at"].split("T")[0] in vid_freq_anti:
        vid_freq_anti[row["published_at"].split("T")[0]] += 1
    else:
        vid_freq_anti[row["published_at"].split("T")[0]] = 1

# %%
ordered_anti = OrderedDict(sorted(vid_freq_anti.items(), key=lambda t: t[0]))

# %%
plt.xticks(rotation=90, fontsize=7)
plt.bar(ordered_anti.keys(), ordered_anti.values(), color='g');
plt.xlabel("Publishing date")
plt.ylabel("Number of 'AntiGov' videos published")
# plt.xticks(list(ordered_pro.keys()));
# Out:
# Text(0, 0.5, "Number of 'AntiGov' videos published")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
custom_list = ['said', 'say', 'one', 'well', 'says', 'know', 'put', 'something', 'another', 'music', 'got', 'talking', 'called', 'go', 'want', 'thing', 'going', 'yeah', 'ye', 'yes', 'new',
               'try', 'oh', 'car']

def remove_stopwords(df, column_name, language='english'):
    stop_words = set(stopwords.words(language))
    df[column_name] = df[column_name].astype(str).apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words and word.lower() not in custom_list]))
    return df

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

df = remove_stopwords(df, 'transcripts')

comment_words = ''
stopwords = set(STOPWORDS)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df[df["published_at"].apply(lambda x: x.split("-")[1]) == "01"]
# Out:
#       Unnamed: 0      videoId  \
# 69            88  t571gMQ4QRU
# 70            89  F5TXuKHLzTY
# 71            90  DbnrHyuqU_Y
# 72            92  OnmdsRI6Bvk
# 73            93  L-TRwsQ7JEo
# ...          ...          ...
# 1167        1363  V1pyuUKGEvw
# 1168        1364  qx0a2coAYz4
# 1169        1365  OVUMiE3tCc8
# 1170        1366  mF09iL30OCY
# 1171        1367  j7cN6tGUk2s
#
#                                                   title  \
# 69    Political War Breaks Out Over NSSO Report On U...
# 70    &#39;Minimum Income Guarantee For BPL Families...
# 71    Manikarnika: The Queen of Jhansi review by Raj...
# 72    We Could&#39;ve Offered Loan Waivers But In Pr...
# 73    Breaking News: BJP Is In An Alliance With Shiv...
# ...                                                 ...
# 1167  CBI Selection Panel To Meet On 24th January, 2019
# 1168  Church Body&#39;s Letter Accessed By Republic ...
# 1169  Four Nuns Who Spoke Against Franco Mulakkal Sh...
# 1170  After Being Dumped By SP-BSP, Rahul Gandhi For...
# 1171  Reinstated Interim CBI Director Nageswara Rao ...
#
#                                             description          published_at  \
# 69    The country's unemployment rate was at a 45-ye...  2019-01-31T16:04:59Z
# 70    ElectionEpicentre #RahulGandhi Rahul Gandhi th...  2019-01-29T04:00:02Z
# 71    CNN News18 film critic Rajeev Masand reviews t...  2019-01-25T20:15:43Z
# 72    The assembly election results in 2018 where th...  2019-01-25T12:10:08Z
# 73    A BJP Source tells CNN-News18 that BJP is alre...  2019-01-25T10:06:03Z
# ...                                                 ...                   ...
# 1167  Republic TV is India's no.1 English news chann...  2019-01-16T12:14:38Z
# 1168  Republic TV is India's no.1 English news chann...  2019-01-16T11:29:33Z
# 1169  Republic TV is India's no.1 English news chann...  2019-01-16T11:15:26Z
# 1170  Republic TV is India's no.1 English news chann...  2019-01-15T06:14:38Z
# 1171  Republic TV is India's no.1 English news chann...  2019-01-11T10:56:58Z
#
#              channel                                     thumbnail_url  \
# 69        CNN-News18  https://i.ytimg.com/vi/t571gMQ4QRU/hqdefault.jpg
# 70        CNN-News18  https://i.ytimg.com/vi/F5TXuKHLzTY/hqdefault.jpg
# 71        CNN-News18  https://i.ytimg.com/vi/DbnrHyuqU_Y/hqdefault.jpg
# 72        CNN-News18  https://i.ytimg.com/vi/OnmdsRI6Bvk/hqdefault.jpg
# 73        CNN-News18  https://i.ytimg.com/vi/L-TRwsQ7JEo/hqdefault.jpg
# ...              ...                                               ...
# 1167  Republic World  https://i.ytimg.com/vi/V1pyuUKGEvw/hqdefault.jpg
# 1168  Republic World  https://i.ytimg.com/vi/qx0a2coAYz4/hqdefault.jpg
# 1169  Republic World  https://i.ytimg.com/vi/OVUMiE3tCc8/hqdefault.jpg
# 1170  Republic World  https://i.ytimg.com/vi/mF09iL30OCY/hqdefault.jpg
# 1171  Republic World  https://i.ytimg.com/vi/j7cN6tGUk2s/hqdefault.jpg
#
#                                             transcripts  generated_by_youtube  \
# 69    [Music] rely Akkad anomic what's gonna happen ...                  True
# 70    heard 2019 battery Congress president Rahul Ga...                  True
# 71    biopic Rani Laxmi earliest patriots freedom st...                  True
# 72    [Music] results state assembly elections Decem...                  True
# 73    top BJP sources suggests shifts posturing affe...                  True
# ...                                                 ...                   ...
# 1167  breaking news coming far entire internal battl...                  True
# 1168  leave convent editor dungeon fact official let...                  True
# 1169  pull away uh breaking update Santa Fe's gettin...                  True
# 1170  let's quickly turn attention Congress party sn...                  True
# 1171  pulling away National Council meeting begins B...                  True
#
#      original_lang   views  comments   likes  \
# 69              en    2729        15    28.0
# 70              en     236         2     3.0
# 71              en  413808      1165  2391.0
# 72              en     255         0     5.0
# 73              en   14693        32   141.0
# ...            ...     ...       ...     ...
# 1167            en     361         0     4.0
# 1168            en     705         6    19.0
# 1169            en   16305        47   104.0
# 1170            en     364         3     6.0
# 1171            en    3645        26    85.0
#
#                                           pre_processed  \
# 69    rely Akkad anomic \n   go to happen need \n   ...
# 70    hear 2019 battery Congress \n   president Rahu...
# 71    biopic Rani Laxmi \n   early patriot freedom s...
# 72    result state assembly \n   elections December ...
# 73    BJP source suggest \n   shift posturing affect...
# ...                                                 ...
# 1167  breaking news come far \n   entire internal ba...
# 1168  oh leave convent editor \n   dungeon fact offi...
# 1169  pull away uh break \n   update Santa Fe gettin...
# 1170  let quickly turn attention \n   Congress party...
# 1171  pull away National \n   Council meeting begin ...
#
#                                                entities    Label
# 69    Akkad -> PERSON\nMatta -> GPE\npune -> GPE\nAy...   ProGov
# 70    2019 -> DATE\nCongress -> ORG\nRahul Gandhi ->...  AntiGov
# 71    Rani Laxmi -> PERSON\nBritish -> NORP\n1858 ->...  Neutral
# 72    December -> DATE\nBJP -> ORG\nindian -> NORP\n...   ProGov
# 73    BJP -> ORG\nCena -> PERSON\nBJP -> ORG\nBJP ->...   ProGov
# ...                                                 ...      ...
# 1167  CBI -> ORG\nCBI -> ORG\nAlok Varma -> PERSON\n...  Neutral
# 1168  Jesus -> PERSON\nAlfea -> PERSON\nJesus -> PER...  Neutral
# 1169  Santa Fe -> ORG\nFranco -> PERSON\nKerala -> G...  AntiGov
# 1170  Congress -> ORG\nAkhilesh Yadav -> PERSON\nnot...  Neutral
# 1171  National \n    -> ORG\nBJP -> ORG\nCBI -> ORG\...  Neutral
#
# [229 rows x 16 columns]

# %%
# iterate through the csv file
new_df = df[df["published_at"].apply(lambda x: x.split("-")[1]) == "01"]

for val in new_df.transcripts:

	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()

	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()

	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# iterate through the csv file
new_df = df[df["published_at"].apply(lambda x: x.split("-")[1]) == "02"]

for val in new_df.transcripts:

	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()

	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()

	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# iterate through the csv file
new_df = df[df["published_at"].apply(lambda x: x.split("-")[1]) == "03"]

for val in new_df.transcripts:

	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()

	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()

	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# iterate through the csv file
new_df = df[df["published_at"].apply(lambda x: x.split("-")[1]) == "04"]

for val in new_df.transcripts:

	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()

	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()

	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
